# %% [markdown]
# <a href="https://colab.research.google.com/github/princegulia154/RL/blob/main/Experiment_2_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(1)

x=np.random.randint(0,50,1000)

y=x+np.random.normal(0,10,1000)


np.corrcoef(x,y)

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
y=100-x+np.random.normal(0,10,1000)

np.corrcoef(x,y)

matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.81143799],
#        [-0.81143799,  1.        ]])

# %%
x=np.random.randint(0,50,1000)

y=np.random.normal(0,10,1000)


np.corrcoef(x,y)
# Out:
# array([[1.        , 0.02749182],
#        [0.02749182, 1.        ]])

# %%
import numpy as np

np.random.seed(1)

x=np.random.randint(0,50,1000)

y=np.random.normal(0,10,1000)


np.corrcoef(x,y)

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.01113712],
#        [-0.01113712,  1.        ]])

# %%
import pandas as pd
df= pd.DataFrame({'a' : np.random.randint(0,50,1000)})
df['b']= df['a'] + np.random.normal (0,10,1000)
df['c']= 100-df['a'] + np.random.normal(0,5,1000)
df['d']= np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.824686 -0.943432 -0.017157
# b  0.824686  1.000000 -0.770644 -0.018510
# c -0.943432 -0.770644  1.000000  0.006741
# d -0.017157 -0.018510  0.006741  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
